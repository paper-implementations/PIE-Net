# %%
import os
import torch
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path

from src import *

# UnifiedIIDDataset, create_iid_data_loaders, custom_collate_fn

# %%
train_loader, val_loader, test_loader = unified_dataset.create_iid_data_loaders(
    config={
        'datasets': {
                        'mpi_sintel': {'path': 'datasets/mpi_sintel',
                                'enabled': True}
                    },
    'image_size': 256,
    'batch_size': 16,
    'num_workers': 4,
    },
)
# Out:
# MPI_Sintel train paths not found
# Loaded 0 total samples for train split
# Dataset distribution: {}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 train_loader, val_loader, test_loader = unified_dataset.create_iid_data_loaders(
#       2     config={
#       3         'datasets': {
#       4                         'mpi_sintel': {'path': 'datasets/mpi_sintel',
#       5                                 'enabled': True}
#       6                     },
#       7     'image_size': 256,
#       8     'batch_size': 16,
#       9     'num_workers': 4,
#      10     },
#      11 )
#
# File ~/Downloads/RunningOnServer/PIE-Net/src/unified_dataset.py:737, in create_iid_data_loaders(config)
#     734 """Convenience function to create all data loaders"""
#     735 loader_factory = IIDDataLoader(config)
# ...
